# %% [markdown]
# # Counting Nouns -Plural and Singular Nouns

# %% [markdown]
# In this recipe, we will do two things:
#
# • Determine whether a noun is plural or singular
#
# • Turn plural nouns into singular nouns and vice versa

# %% [markdown]
# You might need these two things in a variety of tasks:
#
# a. in making your chatbot speak in
# grammatically correct sentences,
#
# b. in coming up with text classifcation features, and so on.

# %%
# !pip install inflect

# %%
# !python -m spacy download en_core_web_md

# %%
# !pip install textacy

# %%
# !pip install spacy-experimental # modern alternative to neuralcoref

# %% [markdown]
# IMPORT LIBRARIES

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import inflect

# %% [markdown]
# READ IN THE TEXT FILE

# %%
file = open(r"/content/001_Study_in_Scarlet.txt", "r", encoding = "utf-8")
Study_in_Scarlet = file.read()

# %% [markdown]
# REMOVE NEW LINES FOR BETTER READABILITY

# %%
Study_in_Scarlet = Study_in_Scarlet.replace("\n", " ")

# %% [markdown]
# DO PART OF SPEECH TAGGING

# %%
import spacy
# Load the model once
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(Study_in_Scarlet)
words_with_pos = [(token.text, token.tag_) for token in doc]

# %% [markdown]
# DEFINE THE GET_NOUNS FUNCTION, WHICH WILL FILTER OUT THE NOUNS FROM THE WORDS

# %%
def get_nouns(word_with_pos):
  noun_set = ["NN", "NNS"]
  nouns = [word for word in words_with_pos if word[1] in noun_set]
  return nouns

# %% [markdown]
# RUN THE PRECEDING FUNCTION ON THE LIST OF POS-TAGGED WORDS AND PRINT IT:

# %%
nouns = get_nouns(words_with_pos)
print(nouns)
# Out:
# [('Study', 'NN'), ('REPRINT', 'NN'), ('REMINISCENCES', 'NNS'), ('-Mr', 'NN'), ('year', 'NN'), ('degree', 'NN'), ('course', 'NN'), ('surgeons', 'NNS'), ('army', 'NN'), ('studies', 'NNS'), ('regiment', 'NN'), ('time', 'NN'), ('war', 'NN'), ('corps', 'NN'), ('passes', 'NNS'), ('enemy', 'NN'), ('country', 'NN'), ('officers', 'NNS'), ('situation', 'NN'), ('safety', 'NN'), ('regiment', 'NN'), ('duties', 'NNS'), ('campaign', 'NN'), ('promotion', 'NN'), ('nothing', 'NN'), ('misfortune', 'NN'), ('disaster', 'NN'), ('brigade', 'NN'), ('battle', 'NN'), ('shoulder', 'NN'), ('bullet', 'NN'), ('bone', 'NN'), ('artery', 'NN'), ('hands', 'NNS'), ('devotion', 'NN'), ('courage', 'NN'), ('orderly', 'NN'), ('pack', 'NN'), ('horse', 'NN'), ('lines', 'NNS'), ('pain', 'NN'), ('hardships', 'NNS'), ('train', 'NN'), ('sufferers', 'NNS'), ('hospital', 'NN'), ('wards', 'NNS'), ('verandah', 'NN'), ('fever', 'NN'), ('curse', 'NN'), ('possessions', 'NNS'), ('months', 'NNS'), ('life', 'NN'), ('board', 'NN'), ('day', 'NN'), ('troopship', 'NN'), ('month', 'NN'), ('health', 'NN'), ('permission', 'NN'), ('government', 'NN'), ('months', 'NNS'), ('air', 'NN'), ('income', 'NN'), ('shillings', 'NNS'), ('sixpence', 'NN'), ('day', 'NN'), ('man', 'NN'), ('circumstances', 'NNS'), ('cesspool', 'NN'), ('loungers', 'NNS'), ('idlers', 'NNS'), ('time', 'NN'), ('hotel', 'NN'), ('comfortless', 'NN'), ('existence', 'NN'), ('money', 'NN'), ('state', 'NN'), ('finances', 'NNS'), ('metropolis', 'NN'), ('country', 'NN'), ('alteration', 'NN'), ('style', 'NN'), ('living', 'NN'), ('alternative', 'NN'), ('mind', 'NN'), ('hotel', 'NN'), ('quarters', 'NNS'), ('domicile', 'NN'), ('day', 'NN'), ('conclusion', 'NN'), ('someone', 'NN'), ('shoulder', 'NN'), ('round', 'NN'), ('dresser', 'NN'), ('Barts', 'NNS'), ('sight', 'NN'), ('face', 'NN'), ('wilderness', 'NN'), ('thing', 'NN'), ('man', 'NN'), ('days', 'NNS'), ('crony', 'NN'), ('mine', 'NN'), ('enthusiasm', 'NN'), ('turn', 'NN'), ('exuberance', 'NN'), ('joy', 'NN'), ('lunch', 'NN'), ('hansom', 'NN'), ('wonder', 'NN'), ('streets', 'NNS'), ('lath', 'NN'), ('nut', 'NN'), ('sketch', 'NN'), ('adventures', 'NNS'), ('time', 'NN'), ('destination', 'NN'), ('devil', 'NN'), ('misfortunes', 'NNS'), ('lodgings', 'NNS'), ('problem', 'NN'), ('rooms', 'NNS'), ('price', 'NN'), ('thing', 'NN'), ('companion', 'NN'), ('man', 'NN'), ('day', 'NN'), ('expression', 'NN'), ('fellow', 'NN'), ('laboratory', 'NN'), ('hospital', 'NN'), ('morning', 'NN'), ('someone', 'NN'), ('halves', 'NNS'), ('rooms', 'NNS'), ('purse', 'NN'), ('gif', 'NN'), ('one', 'NN'), ('rooms', 'NNS'), ('expense', 'NN'), ('man', 'NN'), ('partner', 'NN'), ('wine', 'NN'), ('glass', 'NN'), ('companion', 'NN'), ('anything', 'NN'), ('queer', 'NN'), ('ideas', 'NNS'), ('enthusiast', 'NN'), ('branches', 'NNS'), ('science', 'NN'), ('fellow', 'NN'), ('student', 'NN'), ('idea', 'NN'), ('anatomy', 'NN'), ('class', 'NN'), ('chemist', 'NN'), ('classes', 'NNS'), ('studies', 'NNS'), ('lot', 'NN'), ('way', 'NN'), ('knowledge', 'NN'), ('professors', 'NNS'), ('man', 'NN'), ('fancy', 'NN'), ('anyone', 'NN'), ('man', 'NN'), ('habits', 'NNS'), ('noise', 'NN'), ('excitement', 'NN'), ('remainder', 'NN'), ('existence', 'NN'), ('friend', 'NN'), ('yours', 'NNS'), ('laboratory', 'NN'), ('companion', 'NN'), ('place', 'NN'), ('weeks', 'NNS'), ('morning', 'NN'), ('night', 'NN'), ('luncheon', 'NN'), ('conversation', 'NN'), ('channels', 'NNS'), ('way', 'NN'), ('hospital', 'NN'), ('particulars', 'NNS'), ('gentleman', 'NN'), ('fellow', 'NN'), ('lodger', 'NN'), ('nothing', 'NN'), ('laboratory', 'NN'), ('arrangement', 'NN'), ('part', 'NN'), ('company', 'NN'), ('companion', 'NN'), ('reason', 'NN'), ('hands', 'NNS'), ('matter', 'NN'), ('fellow', 'NN'), ('temper', 'NN'), ('laugh', 'NN'), ('tastes', 'NNS'), ('bloodedness', 'NN'), ('friend', 'NN'), ('pinch', 'NN'), ('vegetable', 'NN'), ('alkaloid', 'NN'), ('malevolence', 'NN'), ('spirit', 'NN'), ('inquiry', 'NN'), ('order', 'NN'), ('idea', 'NN'), ('effects', 'NNS'), ('justice', 'NN'), ('rea ...

# %% [markdown]
# To determine whether a noun is singular or plural, we have two options. The
# first option is to use the NLTK tags, where NN indicates a singular noun and NNS
# indicates a plural noun. The following function uses the NLTK tags and returns
# True if the input noun is plural:

# %%
def is_plural_nltk(noun_info):
  pos = noun_info[1]
  if (pos == "NNS"):
    return True
  else:
    return False

# %% [markdown]
# The other option is to use the WordNetLemmatizer class in the nltk.stem
# package. The following function returns True if the noun is plural:

# %%
def is_plural_wn(noun):
  wnl = WordNetLemmatizer()
  lemma = wnl.lemmatize(noun, "n")

  plural = True if noun is not lemma else False
  return plural

# %% [markdown]
# The following function will change a singular noun into plural:

# %%
def get_plural(singular_noun):
  p = inflect.engine()
  return p.plural(singular_noun)

# %% [markdown]
# The following function will change a plural noun into singular:

# %%
def get_singular(plural_noun):
  p = inflect.engine()
  plural = p.singular_noun(plural_noun)
  if (plural):
    return plural
  else:
    return plural_noun

# %% [markdown]
# We can now use the two preceding functions to return a list of nouns changed into
# plural or singular, depending on the original noun. The following code uses the
# is_plural_wn function to determine if the noun is plural. You can also use the
# is_plural_nltk function:

# %%
def plurals_wn(words_with_pos):
  other_nouns = []
  for noun_info in words_with_pos:
    word = noun_info[0]
    plural = is_plural_wn(word)
    plural = is_plural_wn(word)
    if (plural):
      singular = get_singular(word)
      other_nouns.append(singular)
    else:
      plural = get_plural(word)
      other_nouns.append(plural)
  return other_nouns

# %% [markdown]
# Use the preceding function to return a list of changed nouns:

# %%
import nltk
nltk.download("wordnet")
other_nouns_wn = plurals_wn(nouns)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
print(other_nouns_wn)
# Out:
# ['Studys', 'REPRINTS', 'REMINISCENCE', '-Mrs', 'years', 'degrees', 'courses', 'surgeon', 'armies', 'study', 'regiments', 'times', 'wars', 'corps', 'pass', 'enemies', 'countries', 'officer', 'situations', 'safeties', 'regiments', 'duty', 'campaigns', 'promotions', 'nothings', 'misfortunes', 'disasters', 'brigades', 'battles', 'shoulders', 'bullets', 'bones', 'arteries', 'hand', 'devotions', 'courages', 'orderlies', 'packs', 'horses', 'line', 'pains', 'hardship', 'trains', 'sufferer', 'hospitals', 'ward', 'verandahs', 'fevers', 'curses', 'possession', 'month', 'lives', 'boards', 'days', 'troopships', 'months', 'healths', 'permissions', 'governments', 'month', 'airs', 'incomes', 'shilling', 'sixpences', 'days', 'men', 'circumstance', 'cesspools', 'lounger', 'idler', 'times', 'hotels', 'comfortlesses', 'existences', 'monies', 'states', 'finance', 'metropolises', 'countries', 'alterations', 'styles', 'livings', 'alternatives', 'minds', 'hotels', 'quarter', 'domiciles', 'days', 'conclusions', 'someones', 'shoulders', 'rounds', 'dressers', 'Bartss', 'sights', 'faces', 'wildernesses', 'things', 'men', 'day', 'cronies', 'ours', 'enthusiasms', 'turns', 'exuberances', 'joys', 'lunches', 'hansoms', 'wonders', 'street', 'laths', 'nuts', 'sketches', 'adventure', 'times', 'destinations', 'devils', 'misfortune', 'lodging', 'problems', 'room', 'prices', 'things', 'companions', 'men', 'days', 'expressions', 'fellows', 'laboratories', 'hospitals', 'mornings', 'someones', 'half', 'room', 'purses', 'gifs', 'ones', 'room', 'expenses', 'men', 'partners', 'wines', 'glasses', 'companions', 'anythings', 'queers', 'idea', 'enthusiasts', 'branch', 'sciences', 'fellows', 'students', 'ideas', 'anatomies', 'classes', 'chemists', 'class', 'study', 'lots', 'ways', 'knowledges', 'professor', 'men', 'fancies', 'anyones', 'men', 'habit', 'noises', 'excitements', 'remainders', 'existences', 'friends', 'your', 'laboratories', 'companions', 'places', 'week', 'mornings', 'nights', 'luncheons', 'conversations', 'channel', 'ways', 'hospitals', 'particular', 'gentlemans', 'fellows', 'lodgers', 'nothings', 'laboratories', 'arrangements', 'parts', 'companies', 'companions', 'reasons', 'hand', 'matters', 'fellows', 'tempers', 'laughs', 'taste', 'bloodednesses', 'friends', 'pinches', 'vegetables', 'alkaloids', 'malevolences', 'spirits', 'inquiries', 'orders', 'ideas', 'effect', 'justices', 'readinesses', 'passions', 'knowledges', 'excesses', 'subject', 'room', 'sticks', 'shapes', 'subject', 'bruise', 'deaths', 'eye', 'students', 'object', 'study', 'impression', 'lanes', 'sides', 'doors', 'wings', 'hospitals', 'grounds', 'guidings', 'stones', 'staircases', 'ways', 'corridors', 'vistas', 'walls', 'duns', 'door', 'ends', 'passages', 'chemicals', 'laboratories', 'chambers', 'bottle', 'table', 'retort', 'tests', 'tube', 'lamp', 'flickerings', 'flame', 'students', 'rooms', 'tables', 'works', 'sounds', 'step', 'foot', 'cries', 'pleasures', 'companions', 'tests', 'tubes', 'hands', 'res', '-S', 'agents', 'haemoglobins', 'nothings', 'golds', 'ours', 'delights', 'feature', 'hands', 'strengths', 'credits', 'earths', 'questions', 'haemoglobins', 'significances', 'discoveries', 'ours', 'men', 'discoveries', 'year', 'tests', 'bloods', 'stain', 'coats', 'sleeves', 'eagernesses', 'tables', 'bloods', 'bodkins', 'fingers', 'drops', 'bloods', 'chemicals', 'pipettes', 'quantities', 'bloods', 'litres', 'waters', 'mixtures', 'appearances', 'waters', 'proportions', 'bloods', 'doubts', 'reactions', 'vessels', 'crystal', 'drop', 'fluids', 'instants', 'content', 'mahoganies', 'colours', 'dusts', 'bottoms', 'glasses', 'jars', 'hand', 'children', 'toys', 'tests', 'guaiacums', 'tests', 'examinations', 'bloods', 'corpuscle', 'valuelesses', 'stain', 'hour', 'bloods', 'tests', 'hundred', 'mens', 'earths', 'penalties', 'crime', 'case', 'points', 'men', 'crimes', 'month', 'linens', 'clothe', 'stain', 'bloods', 'stain', 'muds', 'stain', 'rusts', 'stain', 'fruits', 'stain', 'questions', 'experts', 'tests', 't ...

# %% [markdown]
# How it works…
# Number detection works in one of two ways. One is by reading the part of speech tag
# assigned by NLTK. If the tag is NN, then the noun is singular, and if it is NNS, then it's
# plural. Te other way is to use the WordNet lemmatizer and to compare the lemma and
# the original word. Te noun is singular if the lemma and the original input noun are the
# same, and plural otherwise.
# To fnd the singular form of a plural noun and the plural form of a singular noun, we
# can use the inflect package. Its plural and singular_noun methods return the
# correct forms.
# In step 1, we import the necessary modules and functions. You can fnd the pos_tag_
# nltk function in this book's GitHub repository, in the Chapter01 module, in the pos_
# tagging.py fle It uses the code we wrote for Chapter 1, Learning NLP Basics. In step
# 2, we read in the fle's contents into a string. In step 3, we remove newlines from the text;
# this is an optional step. In step 4, we use the pos_tag_nltk function defned in the code
# from the previous chapter to tag parts of speech for the words.
# In step 5, we create the get_nouns function, which flters out the words that are singular
# or plural nouns. In this function, we use a list comprehension and keep only words that
# have the NN or NNS tags.
# In step 6, we run the preceding function on the word list and print the result. As you will
# notice, NLTK tags several words incorrectly as nouns, such as cold and precise. Tese
# errors will propagate into the next steps, and it is something to keep in mind when
# working with NLP tasks.

# %% [markdown]
# In steps 7 and 8, we defne two functions to determine whether a noun is singular or
# plural. In step 7, we defne the is_plural_nltk function, which uses NLTK POS
# tagging information to determine if the noun is plural. In step 8, we defne the is_
# plural_wn function, which compares the noun with its lemma, as determined by the
# NLTK lemmatizer. If those two forms are the same, the noun is singular, and if they
# are diﬀerent, the noun is plural. Both functions can return incorrect results that will
# propagate downstream.
# In step 9, we defne the get_plural function, which will return the plural form of the
# noun by using the inflect package. In step 10, we defne the get_singular function,
# which uses the same package to get the singular form of the noun. If there is no output
# from inflect, the function returns the input.
# In step 11, we defne the plurals_wn function, which takes in a list of words with the
# parts of speech that we got in step 6 and changes plural nouns into singular and singular
# nouns into plural.
# In step 12, we run the plurals_wn function on the nouns list. Most of the words are
# changed correctly; for example, women and emotion. We also see two kinds of error
# propagation, where either the part of speech or number of the noun were determined
# incorrectly. For example, the word akins appears here because akin was incorrectly labeled
# as a noun. On the other hand, the word men was incorrectly determined to be singular
# and resulted in the wrong output; that is, mens.
