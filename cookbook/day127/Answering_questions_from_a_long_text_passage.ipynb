# %% [markdown]
# # Answering questions from a long text passage

# %% [markdown]
# In the previous recipe, we learned an approach to extract the answer to a question, given a context. This pattern involves the model retrieving the answer from the given context. The model cannot answer a question that is not contained in the context. This does serve a purpose where we want an answer from a given context. This type of question-answering system is defined as **Closed Domain Question Answering (CDQA)**.

# %% [markdown]
# There is another system of question answering that can answer questions that are general in nature. These systems are trained on larger corpora. This training provides them with the ability to answer questions that are open in nature. These systems are called **Open Domain Question Answering (ODQA)** systems.

# %% [markdown]
# Getting ready
#
# As part of this recipe, we will use the **DeepPavlov** (https://deeppavlov.ai) ODQA system to answer an open question. We will use the deeppavlov library along with the **Knowledge Base Question Answering (KBQA)** model. This model has been trained on English wiki data as a knowledge base. It uses various NLP techniques such as entity linking and disambiguation, knowledge graphs, and so on to extract the exact answer to the question.

# %% [markdown]
# Install and download the document corpus

# %%
# Install Python 3.10
# !sudo apt-get update -y
# !sudo apt-get install python3.10 python3.10-distutils python3-pip -y

# %%
# Set Python 3.10 as the default 'python3' command
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.10 1
# !sudo update-alternatives --set python3 /usr/bin/python3.10

# %%
# Re-install Pip for the new Python version
#!curl -sS https://bootstrap.pypa.io/get-pip.py | python3

# %%
# !pip install deeppavlov

# %%
# 1. Install the specific Python 3.10 development headers
# (This provides the "blueprints" the compiler needs)
#!sudo apt-get install python3.10-dev build-essential -y

# %%
# 2. Install the build-time Python dependencies
# !pip install --upgrade pip setuptools wheel
# !pip install pybind11 Cython

# %%
# 1. Ensure pybind11 is definitely in the environment
# !pip install pybind11

# %%
# 2. Force install hdt using the current environment's tools
# !pip install hdt==2.3 --no-build-isolation
# Out:
# Requirement already satisfied: hdt==2.3 in /usr/local/lib/python3.10/dist-packages (2.3)
# Requirement already satisfied: pybind11==2.2.4 in /usr/local/lib/python3.10/dist-packages (from hdt==2.3) (2.2.4)

# %%
# !pip install "numpy>=1.18.0" "pandas==2.2.2" "scikit-learn==1.6.1"

# %%
# 1. Clear the pip cache to stop it from using that corrupted .tar.gz file
# !pip cache purge

# %%
# 1. Install Python 3.10 and the specific distutils it needs
# !apt-get install python3.10 python3.10-distutils -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'python3-distutils' instead of 'python3.10-distutils'
# python3-distutils is already the newest version (3.10.8-1~22.04).
# python3.10 is already the newest version (3.10.12-1~22.04.12).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %%
# 2. Get the specific pip for Python 3.10
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# Out:
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-25.3

# %%
# 3. Use the Python 3.10 Pip specifically to install DeepPavlov
# We use 'python3.10 -m pip' to avoid any confusion with the system pip
# !python3.10 -m pip install deeppavlov
# Out:
# Requirement already satisfied: deeppavlov in /usr/local/lib/python3.10/dist-packages (1.7.0)
# Requirement already satisfied: fastapi<=0.89.1,>=0.47.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.89.1)
# Requirement already satisfied: filelock<3.10.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (3.9.1)
# Requirement already satisfied: nltk<3.10.0,>=3.2.4 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (3.9.2)
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.23.5)
# Requirement already satisfied: pandas<1.6.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.5.3)
# Requirement already satisfied: prometheus-client<=1.16.0,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.23.1)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.10.26)
# Collecting pybind11==2.10.3 (from deeppavlov)
#   Using cached pybind11-2.10.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: requests<3.0.0,>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (2.32.5)
# Requirement already satisfied: tqdm<4.65.0,>=4.42.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (4.64.1)
# Requirement already satisfied: uvicorn<0.19.0,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.18.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (0.45.1)
# Requirement already satisfied: scikit-learn<1.1.0,>=0.24 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.0.2)
# Requirement already satisfied: scipy==1.10.0 in /usr/local/lib/python3.10/dist-packages (from deeppavlov) (1.10.0)
# Requirement already satisfied: starlette==0.22.0 in /usr/local/lib/python3.10/dist-packages (from fastapi<=0.89.1,>=0.47.0->deeppavlov) (0.22.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (4.12.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (3.11)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette==0.22.0->fastapi<=0.89.1,>=0.47.0->deeppavlov) (4.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<3.10.0,>=3.2.4->deeppavlov) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<1.6.0,>=1.0.0->deeppavlov) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.19.0->deeppavlov) (2026.1.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.1.0,>=0.24->deeppavlov) (3.6.0)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn<0.19.0,>=0.13.0->deeppavlov) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<1.6.0,>=1.0.0->deeppavlov) (1.16.0)
# Using cached pybind11-2.10.3-py3-none-any.whl (222 kB)
# Installing collected packages: pybind11
#   Attempting uninstall: pybind11
#     Found existing installation: pybind11 2.2.4
#     Uninstalling pybind11-2.2.4:
#       Successfully uninstalled pybind11-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# hdt 2.3 requires pybind11==2.2.4, but you have pybind11 2.10.3 which is incompatible.
# Successfully installed pybind11-2.10.3

# %%
# 4. Install the HDT library (which you succeeded with earlier)
# !python3.10 -m pip install hdt==2.3 --no-build-isolation
# Out:
# Requirement already satisfied: hdt==2.3 in /usr/local/lib/python3.10/dist-packages (2.3)
# Collecting pybind11==2.2.4 (from hdt==2.3)
#   Using cached pybind11-2.2.4-py2.py3-none-any.whl.metadata (2.4 kB)
# Using cached pybind11-2.2.4-py2.py3-none-any.whl (145 kB)
# Installing collected packages: pybind11
#   Attempting uninstall: pybind11
#     Found existing installation: pybind11 2.10.3
#     Uninstalling pybind11-2.10.3:
#       Successfully uninstalled pybind11-2.10.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# deeppavlov 1.7.0 requires pybind11==2.10.3, but you have pybind11 2.2.4 which is incompatible.
# Successfully installed pybind11-2.2.4

# %%
# 5. Run the model install using the 3.10 executable
# !python3.10 -m deeppavlov install kbqa_cq_en
# Out:
# Requirement already satisfied: protobuf<=3.20 in /usr/local/lib/python3.10/dist-packages (3.20.0)
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 23.4 MB/s  0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.5.0) (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.26)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2026.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.3.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.1)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.26)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.3.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy) (0.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy) (2.0.1)
# Ignoring transformers: markers 'python_version < "3.8"' don't match your environment
# Requirement already satisfied: transformers==4.30.0 in /usr/local/lib/python3.10/dist-packages (4.30.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (3.9.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (2.32.5)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.0) (4.64.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.0) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.30.0) (2026.1.4)
# Collecting ru-core-news-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.5.0/ru_core_news_sm-3.5.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 22.1 MB/s  0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.5.0) (3.5.4)
# Requirement already satisfied: pymorphy3>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ru-core-news-sm==3.5.0) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.0.12)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.9.4)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (1.10.26)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (80.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.5.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2026.1.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (8.3.1)
# Requirement already satisfied: pathlib-abc==0.1.1 in /usr/local/lib/python3.10/dist-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (0.1.1)
# Requirement already satisfied: dawg2-python>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in /usr/local/lib/python3.10/dist-packages (from pymorphy3>=1.0.0->ru-core-news-sm==3.5.0) (2.4.417150.4580142)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->ru-core-news-sm==3.5.0) (2.0.1)
# Requirement already satisfied: hdt==2.3 in /usr/local/lib/python3.10/dist-packages (2.3)
# Requirement already satisfied: pybind11==2.2.4 in /usr/local/lib/python3.10/dist-packages (from hdt==2.3) (2.2.4)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (4.15.0)
# Requirement already satisfied: whapi==0.6.* in /usr/local/lib/python3.10/dist-packages (0.6.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from whapi==0.6.*) (2.32.5)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.10/dist-packages (from whapi==0.6.*) (0.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->whapi==0.6.*) (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->whapi==0.6.*) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->whapi==0.6.*) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->whapi==0.6.*) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->whapi==0.6.*) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->whapi==0.6.*) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->whapi==0.6.*) (2026.1.4)
# Requirement already satisfied: torch<1.14.0,>=1.6.0 in /usr/local/lib/python3.10/dist-packages (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (4.15.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.10/dist-packages (from torch<1.14.0,>=1.6.0) (11.7.99)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<1.14.0,>=1.6.0) (0.45.1)
# Requirement already satisfied: pytorch-crf==0.7.* in /usr/local/lib/python3.10/dist-packages (0.7.2)
# Requirement already satisfied: rapidfuzz==2.1.* in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: jarowinkler<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from rapidfuzz==2.1.*) (1.2.3)
# Requirement already satisfied: sentencepiece==0.2.0 in /usr/local/lib/python3.10/dist-packages (0.2.0)

# %% [markdown]
# Imports

# %%
import sys
sys.path.append('/usr/local/lib/python3.10/dist-packages') # this is to ensure the environment uses python 3.10 instead of 3.12

# %% [markdown]
# In this step, we initialize the KBQA model, kbqa_cq_en, which is passed to the build_model method as an argument. We also set the download argument to True so that the model is downloaded as well in case it is missing locally:

# %%
import sys
import torch.nn as nn

# 1. Re-link the Python 3.10 path
if '/usr/local/lib/python3.10/dist-packages' not in sys.path:
    sys.path.append('/usr/local/lib/python3.10/dist-packages')

# 2. Use a "Guard" to prevent recursion even if the cell is run twice
if not hasattr(nn.Module, '_is_patched'):
    print("Applying atomic patch...")
    _original_load = nn.Module.load_state_dict

    def universal_load_patch(self, *args, **kwargs):
        kwargs['strict'] = False  # Ignore the 'position_ids' error
        return _original_load(self, *args, **kwargs)

    nn.Module.load_state_dict = universal_load_patch
    nn.Module._is_patched = True
    print("Patch applied safely.")
else:
    print("Patch already active, skipping to avoid recursion.")

# 3. Now load the model
from deeppavlov import build_model, configs
kbqa_model = build_model(configs.kbqa.kbqa_cq_en, download=True)
# Out:
# Patch already active, skipping to avoid recursion.
# 2026-01-08 20:01:37.496 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/query_prediction_eng.pickle download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/query_prediction_eng.pickle download because of matching hashes
# 2026-01-08 20:01:39.993 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/models/path_ranking_nll_roberta_lcquad2.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/models/path_ranking_nll_roberta_lcquad2.tar.gz download because of matching hashes
# 2026-01-08 20:01:41.288 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/datasets/lcquad2.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/datasets/lcquad2.tar.gz download because of matching hashes
# 2026-01-08 20:01:51.918 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/v1/ner/ner_ontonotes_bert_torch_crf.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/v1/ner/ner_ontonotes_bert_torch_crf.tar.gz download because of matching hashes
# 2026-01-08 20:02:14.938 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/wikidata_full.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/wikidata_full.tar.gz download because of matching hashes
# 2026-01-08 20:02:15.801 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/kbqa_files_en.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/kbqa_files_en.tar.gz download because of matching hashes
# 2026-01-08 20:02:20.215 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/models/entity_type_detection_distilbert_lcquad2.0.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/models/entity_type_detection_distilbert_lcquad2.0.tar.gz download because of matching hashes
# 2026-01-08 20:02:22.639 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/models/rel_ranking_roberta_en.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/models/rel_ranking_roberta_en.tar.gz download because of matching hashes
# 2026-01-08 20:02:24.20 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/query_prediction_eng.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/query_prediction_eng.tar.gz download because of matching hashes
# 2026-01-08 20:02:28.660 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/downloads/el_db_lcquad2.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/downloads/el_db_lcquad2.tar.gz download because of matching hashes
# 2026-01-08 20:02:29.295 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/queries_and_rels_lcquad2_v2.tar.gz download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/queries_and_rels_lcquad2_v2.tar.gz download because of matching hashes
# 2026-01-08 20:02:29.974 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/kbqa/wikidata/lcquad_rel_ranking.pickle download because of matching hashes
# INFO:deeppavlov.download:Skipped http://files.deeppavlov.ai/kbqa/wikidata/lcquad_rel_ranking.pickle download because of matching hashes
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at haisongzhang/roberta-tiny-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2026-01-08 20:02:30.758 WARNING in 'deeppavlov.core.models.torch_model'['torch_model'] at line 96: Unable to place component TorchTransformersClassifierModel on GPU, since no CUDA GPUs are available. Using CPU.
# WARNING:deeppavlov.core.models.torch_model:Unable to place component TorchTransformersClassifierModel on GPU, since no CUDA GPUs are available. Using CPU.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-328932396.py in <cell line: 0>()
#      23 # 3. Now load the model
#      24 from deeppavlov import build_model, configs
# ---> 25 kbqa_model = build_model(configs.kbqa.kbqa_cq_en, download=True)
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/commands/infer.py in build_model(config, mode, load_trained, install, download)
#      53                             .format(component_config.get('class_name', component_config.get('ref', 'UNKNOWN'))))
#      54
# ---> 55         component = from_params(component_config, mode=mode)
#      56
#      57         if 'id' in component_config:
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/params.py in from_params(params, mode, **kwargs)
#      90         log.exception(e)
#      91         raise e
# ---> 92     obj = get_model(cls_name)
#      93
#      94     if inspect.isclass(obj):
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/registry.py in get_model(name)
#      72             raise ConfigError("Model {} is not registered.".format(name))
#      73         return cls_from_str(name)
# ---> 74     return cls_from_str(_REGISTRY[name])
#      75
#      76
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/registry.py in cls_from_str(name)
#      40                           .format(name))
#      41
# ---> 42     return getattr(importlib.import_module(module_name), cls_name)
#      43
#      44
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.12/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/models/kbqa/query_generator.py in <module>
#      25 from deeppavlov.core.common.registry import register
#      26 from deeppavlov.core.models.component import Component
# ---> 27 from deeppavlov.models.kbqa.query_generator_base import QueryGeneratorBase
#      28 from deeppavlov.models.kbqa.rel_ranking_infer import RelRankerInfer
#      29 from deeppavlov.models.kbqa.utils import extract_year, extract_number, make_combs, fill_query, find_query_features, \
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/models/kbqa/query_generator_base.py in <module>
#      25 from deeppavlov.core.models.component import Component
#      26 from deeppavlov.core.models.serializable import Serializable
# ---> 27 from deeppavlov.models.entity_extraction.entity_linking import EntityLinker
#      28 from deeppavlov.models.kbqa.rel_ranking_infer import RelRankerInfer
#      29 from deeppavlov.models.kbqa.template_matcher import TemplateMatcher
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/models/entity_extraction/entity_linking.py in <module>
#      21 import nltk
#      22 import spacy
# ---> 23 from hdt import HDTDocument
#      24 from nltk.corpus import stopwords
#      25 from rapidfuzz import fuzz
#
# ModuleNotFoundError: No module named 'hdt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# We use the initialized model and pass it a couple of questions that we want to be answered:

# %%
from transformers import PreTrainedTokenizerFast

# 1. Restore the original method first to avoid nested loops
from transformers.tokenization_utils_fast import PreTrainedTokenizerFast as BaseTokenizer
PreTrainedTokenizerFast._batch_encode_plus = BaseTokenizer._batch_encode_plus

_original_batch_encode = PreTrainedTokenizerFast._batch_encode_plus

# 2. Define the "clean" patch
def final_tokenizer_patch(self, *args, **kwargs):
    # Remove the arguments that the Fast Tokenizer's C++ core rejects
    kwargs.pop('pad_to_max_length', None)
    kwargs.pop('padding', None)
    kwargs.pop('truncation', None)

    return _original_batch_encode(self, *args, **kwargs)

# 3. Apply the patch
PreTrainedTokenizerFast._batch_encode_plus = final_tokenizer_patch
print("Final Tokenizer patch applied! Inter-library argument conflicts resolved.")

# 4. Run your query
result = kbqa_model(["What is the capital of Egypt?",
                     "who is Bill Clinton's wife?"])
# Out:
# Final Tokenizer patch applied! Inter-library argument conflicts resolved.
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipython-input-432698070.py in <cell line: 0>()
#      21
#      22 # 4. Run your query
# ---> 23 result = kbqa_model(["What is the capital of Egypt?",
#      24                      "who is Bill Clinton's wife?"])
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/chainer.py in __call__(self, *args)
#     205
#     206     def __call__(self, *args):
# --> 207         return self._compute(*args, param_names=self.in_x, pipe=self.pipe, targets=self.out_params)
#     208
#     209     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/chainer.py in _compute(***failed resolving arguments***)
#     228                 res = component.__call__(**dict(zip(in_keys, x)))
#     229             else:
# --> 230                 res = component.__call__(*x)
#     231             if len(out_params) == 1:
#     232                 mem[out_params[0]] = res
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/chainer.py in __call__(self, *args)
#     205
#     206     def __call__(self, *args):
# --> 207         return self._compute(*args, param_names=self.in_x, pipe=self.pipe, targets=self.out_params)
#     208
#     209     @staticmethod
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/core/common/chainer.py in _compute(***failed resolving arguments***)
#     228                 res = component.__call__(**dict(zip(in_keys, x)))
#     229             else:
# --> 230                 res = component.__call__(*x)
#     231             if len(out_params) == 1:
#     232                 mem[out_params[0]] = res
#
# /usr/local/lib/python3.10/dist-packages/deeppavlov/models/preprocessors/torch_transformers_preprocessor.py in __call__(self, texts_a, texts_b)
#     160         texts_a = [k for k in texts_a if k is not None]  # handle dummy output
#     161
# --> 162         input_features = self.tokenizer(text=texts_a,
#     163                                         text_pair=texts_b,
#     164                                         add_special_tokens=True,
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in __call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3071             if not self._in_target_context_manager:
#    3072                 self._switch_to_input_mode()
# -> 3073             encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    3074         if text_target is not None:
#    3075             self._switch_to_target_mode()
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in _call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3159                 )
#    3160             batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 3161             return self.batch_encode_plus(
#    3162                 batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3163                 add_special_tokens=add_special_tokens,
#
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py in batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3360         )
#    3361
# -> 3362         return self._batch_encode_plus(
#    3363             batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3364             add_special_tokens=add_special_tokens,
#
# /tmp/ipython-input-432698070.py in final_tokenizer_patch(self, *args, **kwargs)
#      14     kwargs.pop('truncation', None)
#      15
# ---> 16     return _original_batch_encode(self, *args, **kwargs)
#      17
#      18 # 3. Apply the patch
#
# /tmp/ipython-input-3823094285.py in final_tokenizer_patch(self, *args, **kwargs)
#      14     kwargs.pop('truncation', None)
#      15
# ---> 16     return _original_batch_encode(self, *args, **kwargs)
#      17
#      18 # 3. Apply the patch
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipython-input-3823094285.py in final_tokenizer_patch(self, *args, **kwargs)
#      14     kwargs.pop('truncation', None)
#      15
# ---> 16     return _original_batch_encode(self, *args, **kwargs)
#      17
#      18 # 3. Apply the patch
#
# RecursionError: maximum recursion depth exceeded
