# %% [markdown]
# # Building a basic chatbot with keyword matching

# %% [markdown]
# # How to do it…
# We will use the NLTK chat framework to create a simple chatbot. First, we will create the
# question-answer pairs and then create the Chat object. We will then use it to converse
# with the bot:

# %% [markdown]
# Install and import Libraries

# %%
! pip install nltk
from nltk.chat.util import Chat, reflections

# %% [markdown]
# Initialize the Coversation pairs

# %%
pairs = [
    [
        r"(hi|hello|hey|what's up)",
        ["Hello, I am a simple chatbot. How are you?"]
    ],
    [
        r".*(how are you|and you).*",
        [
            "Doing well, thank you.",
            "I'm ok, what's new?"
        ]
    ],
    [
        r"quit",
        [
            "Bye, nice talking to you!",
            "Talking to you later!"
        ]
    ],
    [
        r".*(weather|rain|snow|sun).*",
        [
            "Isn't it nice out today?",
            "Hopefully, tomorrow the weather will get better.",
            "I don't know about you, but I am glad I am inside today."
        ]
    ],
    [
        r"I like (.*)",
        [
            "Why do you like %1?",
            "What about %1 do you like?"
        ]
    ],
    [
        r".*(tasty).*",
        ["Yeah, I think so too."]
    ],
    [
        r".*",
        ["I am sorry, I don't understand. I am a very simple chatbot!"]
    ]
]

# %% [markdown]
# Create a new chatbot:

# %%
chatbot = Chat(pairs, reflections)

# %% [markdown]
# Use the chatbot's converse function to carry out the conversation:

# %%
chatbot.converse()
# Out:
# >Hello
# Hello, I am a simple chatbot. How are you?
# >Good, and you?
# I'm ok, what's new?
# >I like pizza
# Why do you like pizza?
# >It's tasty.
# Yeah, I think so too.
# >Do you know know about Natural Language Processing?
# I am sorry, I don't understand. I am a very simple chatbot!
# >quit
# Bye, nice talking to you!

# %% [markdown]
# USING eliza_chat

# %%
from nltk.chat.eliza import eliza_chat

# %%
eliza_chat()
# Out:
# Therapist
# ---------
# Talk to the program by typing in plain English, using normal upper-
# and lower-case letters and punctuation.  Enter "quit" when done.
# ...
# Hello.  How are you feeling today?
# >Hello
# Hi there... how are you today?
# >cool. you?
# Why do you ask that?
# >Because I care.
# Is that the real reason?
# >Yeah
# yeah.
# >Can you tell me something about Natural Language Processing, I am curious?
# What makes you think I can't tell you something about natural language processing, you are curious?
# >I am skeptical of your capability
# Did you come to me because you are skeptical of my capability?
# >no
# no.
# >thank you
# How does that make you feel?
# >quit
# Thank you for talking with me.
