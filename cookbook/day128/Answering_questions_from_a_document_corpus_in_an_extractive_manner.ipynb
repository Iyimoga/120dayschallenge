# %% [markdown]
# # Answering questions from a document corpus in an extractive manner

# %% [markdown]
# For the use cases where we have a document corpus that contains a large number of documents, it’s not feasible to load the document content at runtime to answer a question. Such an approach would lead to long query times and would not be suitable for production-grade systems.

# %% [markdown]
# In this recipe, we will learn how to preprocess the documents and transform them into a form for faster reading, indexing, and retrieval that allows the system to extract the answer for a given question with short query times.

# %% [markdown]
# ### Getting ready
#
# As part of this recipe, we will use the **Haystack** (https://haystack.deepset.ai/) framework to build a **QA system** that can answer questions from a document corpus. We will download a dataset based on Game of Thrones and index it. For our QA system to be performant, we will need to index the documents beforehand. Once the documents are indexed, answering a question follows a two-step process:

# %% [markdown]
#     1. Retriever: Since we have many documents, scanning each document to fetch an answer is not a feasible approach. We will first retrieve a set of candidate documents that can possibly contain an answer to our question. This step is performed using a Retriever component. This searches through the pre-created index to filter the number of documents that we will need to scan to retrieve the exact answer.
#     2. Reader: Once we have a candidate set of documents that could contain the answer, we will search these documents to retrieve the exact answer to our question.

# %% [markdown]
# Imports

# %%
# %pip install farm-haystack
# Out:
# Collecting farm-haystack
#   Downloading farm_haystack-1.26.4.post0-py3-none-any.whl.metadata (28 kB)
# Collecting boilerpy3 (from farm-haystack)
#   Using cached boilerpy3-1.0.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting events (from farm-haystack)
#   Using cached Events-0.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (0.28.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (4.25.1)
# Collecting lazy-imports==0.3.1 (from farm-haystack)
#   Using cached lazy_imports-0.3.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (10.8.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (3.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (4.5.1)
# Collecting posthog (from farm-haystack)
#   Using cached posthog-7.5.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack)
#   Using cached prompthub_py-4.0.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pydantic<2 (from farm-haystack)
#   Using cached pydantic-1.10.26-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (155 kB)
# Collecting quantulum3 (from farm-haystack)
#   Using cached quantulum3-0.9.2-py3-none-any.whl.metadata (16 kB)
# Collecting rank-bm25 (from farm-haystack)
#   Using cached rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (2.32.4)
# Collecting requests-cache<1.0.0 (from farm-haystack)
#   Using cached requests_cache-0.9.8-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (1.6.1)
# Collecting sseclient-py (from farm-haystack)
#   Using cached sseclient_py-1.9.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (9.1.2)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (0.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from farm-haystack) (4.67.1)
# Collecting transformers<5.0,>=4.46 (from farm-haystack)
#   Downloading transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from prompthub-py==4.0.0->farm-haystack) (6.0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2->farm-haystack) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack) (2025.11.12)
# Collecting appdirs>=1.4.4 (from requests-cache<1.0.0->farm-haystack)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<1.0.0->farm-haystack) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack)
#   Using cached cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack)
#   Using cached url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.0,>=4.46->farm-haystack)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0,>=4.46->farm-haystack) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers<5.0,>=4.46->farm-haystack) (1.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->farm-haystack) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->farm-haystack) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->farm-haystack) (3.6.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->farm-haystack) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->farm-haystack) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->farm-haystack) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->farm-haystack) (1.17.0)
# Collecting backoff>=1.10.0 (from posthog->farm-haystack)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog->farm-haystack) (1.9.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.12/dist-packages (from quantulum3->farm-haystack) (7.5.0)
# Collecting num2words (from quantulum3->farm-haystack)
#   Using cached num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect->quantulum3->farm-haystack) (4.4.4)
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack)
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Downloading farm_haystack-1.26.4.post0-py3-none-any.whl (764 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 764.4/764.4 kB 17.0 MB/s  0:00:00
# Using cached lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Using cached prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Using cached pydantic-1.10.26-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.6 MB)
# Using cached requests_cache-0.9.8-py3-none-any.whl (48 kB)
# Downloading transformers-4.57.3-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 62.6 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 81.3 MB/s  0:00:00
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached cattrs-25.3.0-py3-none-any.whl (70 kB)
# Using cached url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Using cached boilerpy3-1.0.7-py3-none-any.whl (22 kB)
# Using cached Events-0.5-py3-none-any.whl (6.8 kB)
# Using cached posthog-7.5.1-py3-none-any.whl (167 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached quantulum3-0.9.2-py3-none-any.whl (10.6 MB)
# Using cached num2words-0.5.14-py3-none-any.whl (163 kB)
# Using cached rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Using cached sseclient_py-1.9.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: events, docopt, appdirs, url-normalize, sseclient-py, rank-bm25, pydantic, num2words, lazy-imports, cattrs, boilerpy3, backoff, requests-cache, prompthub-py, posthog, tokenizers, quantulum3, transformers, farm-haystack
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.12.3
#     Uninstalling pydantic-2.12.3:
#       Successfully uninstalled pydantic-2.12.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [farm-haystack]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 1.2.0 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# langgraph 1.0.5 requires pydantic>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# google-adk 1.21.0 requires pydantic<3.0.0,>=2.0, but you have pydantic 1.10.26 which is incompatible.
# gradio 5.50.0 requires pydantic<=2.12.3,>=2.0, but you have pydantic 1.10.26 which is incompatible.
# pydantic-settings 2.12.0 requires pydantic>=2.7.0, but you have pydantic 1.10.26 which is incompatible.
# langchain-core 1.2.1 requires pydantic<3.0.0,>=2.7.4, but you have pydantic 1.10.26 which is incompatible.
# albumentations 2.0.8 requires pydantic>=2.9.2, but you have pydantic 1.10.26 which is incompatible.
# thinc 8.3.10 requires pydantic<3.0.0,>=2.0.0, but you have pydantic 1.10.26 which is incompatible.
# mcp 1.24.0 requires pydantic<3.0.0,>=2.11.0, but you have pydantic 1.10.26 which is incompatible.
# google-genai 1.55.0 requires pydantic<3.0.0,>=2.9.0, but you have pydantic 1.10.26 which is incompatible.
# Successfully installed appdirs-1.4.4 backoff-2.2.1 boilerpy3-1.0.7 cattrs-25.3.0 docopt-0.6.2 events-0.5 farm-haystack-1.26.4.post0 lazy-imports-0.3.1 num2words-0.5.14 posthog-7.5.1 prompthub-py-4.0.0 pydantic-1.10.26 quantulum3-0.9.2 rank-bm25-0.2.2 requests-cache-0.9.8 sseclient-py-1.9.0 tokenizers-0.22.2 transformers-4.57.3 url-normalize-2.2.1

# %%
import os
from haystack.document_stores import InMemoryDocumentStore
from haystack.nodes import BM25Retriever, FARMReader
from haystack.pipelines import ExtractiveQAPipeline
from haystack.pipelines.standard_pipelines import(
    TextIndexingPipeline)
from haystack.utils import (fetch_archive_from_http,
    print_answers)

# %% [markdown]
# In this step, we specify a folder that will be used to save our dataset. Then, we retrieve the dataset from the source. The second parameter to the fetch_archive_from_http method is the folder in which the dataset will be downloaded. We set the parameter to the folder that we defined in the first line. The fetch_archive_from_http method decompresses the archive .zip file and extracts all files into the same folder. We then read from the folder and create a list of files contained in the folder. We also print the number of files that are present:

# %%
doc_dir = "data/got_dataset"
fetch_archive_from_http(
    url="https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/wiki_gameofthrones_txt1.zip",
    output_dir=doc_dir,
    )
files_to_index = [doc_dir + "/" + f for f in os.listdir(
    doc_dir)]
print(len(files_to_index))
# Out:
# 183

# %% [markdown]
# e initialize a document store based on the files. We create an indexing pipeline based on the document store and execute the indexing operation. To achieve this, we initialize an InMemoryDocumentStore instance. In this method call, we set the use_bm25 argument as True. The document store uses Best Match 25 (bm25) as the algorithm for the retriever step. The bm25 algorithm is a simple bag-of-words-based algorithm that uses a scoring function. This function utilizes the number of times a term is present in the document and the length of the document. Chapter 3 covers the bm25 algorithm in more detail and we recommend you refer to that chapter for better understanding. Note that there are various other DocumentStore options such as ElasticSearch, OpenSearch, and so on. We used an InMemoryDocumentStore document store to keep the recipe simple and focus on the retriever and reader concepts:

# %%
from haystack.document_stores import InMemoryDocumentStore

document_store = InMemoryDocumentStore(use_bm25 = True)
indexing_pipeline = TextIndexingPipeline(document_store)
indexing_pipeline.run_batch(file_paths = files_to_index)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Converting files: 100%|██████████| 183/183 [00:01<00:00, 140.33it/s]
# Preprocessing:   3%|▎         | 5/183 [00:00<00:08, 21.42docs/s]WARNING:haystack.nodes.preprocessor.preprocessor:We found one or more sentences whose split count is higher than the split length.
# Preprocessing:  20%|██        | 37/183 [00:01<00:08, 17.28docs/s]WARNING:haystack.nodes.preprocessor.preprocessor:Document b48fb0da693eb4d81b3566d0069868b3 is 10488 characters long after preprocessing, where the maximum length should be 10000. Something might be wrong with the splitting, check the document affected to prevent issues at query time. This document will be now hard-split at 10000 chars recursively.
# WARNING:haystack.nodes.preprocessor.preprocessor:Document 4189b42892b3d941c035947d512b69dd is 12059 characters long after preprocessing, where the maximum length should be 10000. Something might be wrong with the splitting, check the document affected to prevent issues at query time. This document will be now hard-split at 10000 chars recursively.
# Preprocessing:  92%|█████████▏| 169/183 [00:06<00:00, 32.67docs/s]WARNING:haystack.nodes.preprocessor.preprocessor:Document dd048b8e5bcb7de1be5bd3937f15442f is 14232 characters long after preprocessing, where the maximum length should be 10000. Something might be wrong with the splitting, check the document affected to prevent issues at query time. This document will be now hard-split at 10000 chars recursively.
# Preprocessing: 100%|██████████| 183/183 [00:06<00:00, 27.69docs/s]
# Updating BM25 representation...: 100%|██████████| 2359/2359 [00:00<00:00, 13349.15 docs/s]
# {'documents': [<Document: {'content': "\n\n'''Petyr Baelish''', nicknamed '''Littlefinger''', is a fictional character in the ''A Song of Ice and Fire'' series of fantasy novels by American author George R. R. Martin, and its television adaptation ''Game of Thrones''.\n\nIntroduced in 1996's ''A Game of Thrones'', Littlefinger is the master of coin on King Robert's small council. He is a childhood friend of Catelyn Stark, having grown up with her and her two siblings at Riverrun. He subsequently appeared in Martin's books ''A Clash of Kings'' (1998), ''A Storm of Swords'' (2000), and ''A Feast for Crows'' (2005). He is set to appear in the forthcoming novel ''The Winds of Winter''. Littlefinger's primary character attributes are his cunning and boundless ambition. Originally hailing from a minor family with little wealth or influence, Baelish used manipulation, bribery, and the connections he secured at Riverrun to gain power and prestige in King's Landing. Since then, his various intrigues have directly caused several major events that have impacted Westeros, including the framing of Tyrion Lannister for the attempt on Bran Stark's life, the downfall of Lord Eddard Stark, the deaths of Lord Jon Arryn and King Joffrey Baratheon, and the War of the Five Kings.\n\n", 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id':
, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a1f10ef68bfaa7dabdd9ad7056f2f987'}>,
#   <Document: {'content': '\'\'The Guardian\'\' gave the Xbox 360 version three stars out of five and called it "a decent game that has been horrifically let down by one sub-standard element."However, \'\'The Digital Fix\'\' gave the same console version a score of five out of ten and said, "By hook or by crook Cyanide managed to win this licence before it hit the big time with HBO, and it\'s difficult to believe that they would be given the opportunity to create Westeros now that it is so much more well known. A serviceable game with blood spurts and political machinations would have sufficed as a first step, allowing them time to bed in get to know the nuances of third person combat. Instead, apart from the story, there is a general feeling of detachment from the game and its main gameplay elements giving rise to the notion that most who play it will do so only to find out how the tales of Mors and Alester twist and turn on their way to conclusion."', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 8}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'ce8a17902cb0eab23bccaaacf7b0b9cc'}>,
# ...
#   <Document: {'content': 'Sara Stewart of the \'\'New York Post\'\' pointed out that the rape and sexual abuse of both female and male characters is typical for \'\'Game of Thrones\'\': "Why are we suddenly so outraged about the rape of Sansa Stark, when this show has served up a steady diet of sexual assault and violence against women since its first season began?"Cathy Young of \'\'Reason\'\' magazine, writing in \'\'Time\'\' noted what she calls a lack of complaint in response to the sexual mistreatment of male characters in earlier seasons, specifically the literal emasculation of Theon Greyjoy and the sexual assault of Gendry.\n\nCriticism of the scene has not extended to the quality of the acting. Joanna Robinson of \'\'Vanity Fair\'\' wrote, "And if we can say one positive thing about that scene it\'s that Allen nailed his performance. Theon\'s horror mirrored our own and the camera—focusing on his reaction—let our minds fill in the blanks."Sophie Turner defended the scene as an artistic challenge for herself as an actor, saying, "When I read that scene, I kinda loved it. I love the way Ramsay had Theon watching. It was all so messed up. ', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 34}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '2e8b973c15b469f7aca568e0e696e80c'}>,
#   <Document: {'content': 'It\'s also so daunting for me to do it. ... I think it\'s going to be the most challenging season for me so far, just because it\'s so emotional for her. It\'s not just crying all the time, like seasons 2 or 3, it\'s super messed up."Iwan Rheon (Ramsay Bolton) agreed, referring to Turner\'s performances this season as "absolutely amazing."Some viewers, including U.S. Senator Claire McCaskill, announced that they would stop watching the show because of this scene. According to \'\'Business Insider\'\', this scene and increased use of streaming services are likely reasons why ratings dropped from 6.2 million viewers for this episode to 5.4 million for the next episode, "The Gift."===Recognition and awards===\nSophie Turner has received several award nominations for her portrayal of Sansa including an Emmy nomination for Outstanding Supporting Actress in a Drama Series in 2019. For her performance in the series she earned the Glamour Award for Best UK TV Actress in 2016 and 2017, and an EWwy Award for Best Supporting Actress in a Drama Series in 2016. ', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 35}, 'id_hash_keys': ['content'], 'embedding': None, 'id': '46dede6a2ae98e97e976e5f1e87c819a'}>,
#   <Document: {'content': 'Other nominations include the Young Artist Award for Best Performance in a TV Series by a Supporting Young Actress in 2012, and the EWwy Award for Best Supporting Actress in a Drama Series in 2015.\n\n==References==\n===Inline citations===\n\n===General references===\n*\n*\n*\n*', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 36}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'dd37d6daa497f7efda58c09a480deaa5'}>,
#   <Document: {'content': '\n\n"\'\'\'Mother\'s Mercy\'\'\'" is the fifth season finale episode of HBO\'s fantasy television series \'\'Game of Thrones\'\', and the 50th overall. The tenth and final episode of the fifth season, the episode was written by the series creators David Benioff and D. B. Weiss and directed by David Nutter.\n\n"Mother\'s Mercy" garnered critical acclaim, with critics lauding Lena Headey\'s performance, David Nutter\'s direction and the writing of Benioff and Weiss. Particular praise was directed to Cersei Lannister\'s walk of atonement, which involved a body double and the use of CGI. In the United States, the episode premiere achieved a viewership of 8.11 million, making it the show\'s most watched episode, until it was surpassed by the season six finale, "The Winds of Winter". The episode won Emmy Awards for Writing in a Drama Series and Directing in a Drama Series for Benioff, Weiss, and Nutter.\n\nThis episode marks the final appearance for Stephen Dillane (Stannis Baratheon), Tara Fitzgerald (Selyse Baratheon), and Ian Beattie (Ser Meryn Trant).\n\n==Plot==\n\n===In the North===\nThe weather conditions at Stannis\' camp drastically improve, clearing the route towards Winterfell. Melisandre takes credit, claiming that the Lord of Light is rewarding Stannis for sacrificing Shireen. ', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 0}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'a4725872397d98c52ac8385fe4b1cfea'}>,
#   <Document: {'content': 'However, Stannis\' officers inform him that Shireen\'s sacrifice has also prompted a mass desertion of his troops, leaving him with only half his army and no cavalry, and driven Selyse to hang herself. Melisandre immediately flees to Castle Black. Despite all of these setbacks, Stannis orders his remaining troops to march forward towards Winterfell. As Stannis\' army marches through the Wolfswood, Podrick sees them and warns Brienne, who leaves to take revenge on Stannis.\n\nAs Stannis prepares to besiege the castle, the Bolton cavalry, led by Ramsay, suddenly emerges. It becomes clear they greatly outnumber Stannis\'s army; nonetheless, Stannis leads his men into battle. After a quick yet fierce battle, the Boltons emerge as the victors. Stannis survives the destruction of his army, but is severely wounded after fighting several Bolton soldiers. Brienne then arrives and announces her intentions to execute Stannis for the murder of Renly ("The Ghost of Harrenhal"). Stannis accepts his fate, and Brienne executes him.\n\nMeanwhile, in Winterfell, Sansa escapes her room using the corkscrew she stole and lights a candle in the ruined tower to signal for help, but Brienne has already left. ', 'content_type': 'text', 'score': None, 'meta': {'_split_id': 1}, 'id_hash_keys': ['content'], 'embedding': None, 'id': 'f978cd007a4ecf77a3571f4c3383c1e8'}>,
#   ...],
#  'root_node': 'File',
#  'params': {},
#  'file_paths': ['data/got_dataset/482_Petyr_Baelish.txt',
#   'data/got_dataset/154_Margaery_Tyrell.txt',
#   'data/got_dataset/401_Power_Is_Power.txt',
#   'data/got_dataset/453_Game_of_Thrones__2012_video_game_.txt',
#   'data/got_dataset/191_Gendry.txt',
#   'data/got_dataset/454_Music_of_Game_of_Thrones.txt',
#   'data/got_dataset/207_Jon_Snow__character_.txt',
#   'data/got_dataset/28_Jorah_Mormont.txt',
#   'data/got_dataset/461_The_Winds_of_Winter__Game_of_Thrones_.txt',
#   'data/got_dataset/73_A_Man_Without_Honor.txt',
#   'data/got_dataset/24_Game_of_Thrones__Season_1__soundtrack_.txt',
#   'data/got_dataset/442_Game_of_Thrones__season_1_.txt',
#   'data/got_dataset/210_The_Mountain_and_the_Viper.txt',
#   'data/got_dataset/514_Book_of_the_Stranger.txt',
#   'data/got_dataset/343_Catelyn_Stark.txt',
#   'data/got_dataset/134_Game_of_Thrones__Season_6__soundtrack_.txt',
#   'data/got_dataset/20_Light_of_the_Seven.txt',
#   'data/got_dataset/495_Hodor.txt',
#   'data/got_dataset/43_Arya_Stark.txt',
#   'data/got_dataset/9_Game_of_Thrones_Tapestry.txt',
#   'data/got_dataset/126_Kissed_by_Fire.txt',
#   'data/got_dataset/131_Mhysa.txt',
#   'data/got_dataset/145_Elio_M._García_Jr._and_Linda_Antonsson.txt',
#   'data/got_dataset/480_Varys.txt',
#   'data/got_dataset/11_The_Dragon_and_the_Wolf.txt',
#   'data/got_dataset/213_Valyrian_languages.txt',
#   'data/got_dataset/136_Game_of_Thrones__Season_8__soundtrack_.txt',
#   'data/got_dataset/504_List_of_A_Song_of_Ice_and_Fire_video_games.txt',
#   'data/got_dataset/424_Night_King.txt',
#   'data/got_dataset/55_Breaker_of_Chains.txt',
#   'data/got_dataset/475_A_Game_of_Thrones__role-playing_game_.txt',
#   'data/got_dataset/311_Game_of_Thrones__season_7_.txt',
#   'data/got_dataset/334_Rickon_Stark.txt',
#   'data/got_dataset/201_A_Game_of_Thrones__card_game_.txt',
#   'data/got_dataset/232_Tommen_Baratheon.txt',
#   'data/got_dataset/488_Brienne_of_Tarth.txt',
#   'data/got_dataset/195_World_of_A_Song_of_Ice_and_Fire.txt',
#   'data/got_dataset/379_Davos_Seaworth.txt',
#   'data/got_dataset/214_Dothraki_language.txt',
#   'data/got_dataset/86_Game_of_Thrones__season_4_.txt',
#   'data/got_dataset/396_Game_of_Thrones__season_6_.txt',
#   'data/got_dataset/217_The_Rogue_Prince.txt',
#   'data/got_dataset/445_The_Wolf_and_the_Lion.txt',
#   'data/got_dataset/118_Dark_Wings__Dark_Words.txt',
#   'data/got_dataset/435_White_Walker.txt',
#   'data/got_dataset/360_List_of_Game_of_Thrones_episodes.txt',
#   'data/got_dataset/212_The_Children__Game_of_Thrones_.txt',
#   'data/got_dataset/99_A_Song_of_Ass_and_Fire.txt',
#   'data/got_dataset/452_Fire_and_Blood__Game_of_Thrones_.txt',
#   'data/got_dataset/233_Myrcella_Baratheon.txt',
#   'data/got_dataset/229_Game_of_Thrones.txt',
#   'data/got_dataset/362_Winter_Is_Coming.txt',
#   'data/got_dataset/420_Blood_of_My_Blood.txt',
#   'data/got_dataset/460_Battle_of_the_Bastards.txt',
#   'data/got_dataset/98_Black_Friday__South_Park_.txt',
#   'data/got_dataset/395_Game_of_Thrones__season_5_.txt',
#   'data/got_dataset/399_For_the_Throne__Music_Inspired_by_the_HBO_Series_Game_of_Thrones.txt',
#   'data/got_dataset/378_A_Game_of_Thrones__board_game_.txt',
#   'data/got_dataset/194_A_Song_of_Ice_and_Fire.txt',
#   'data/got_dataset/342_Theon_Greyjoy.txt',
#   'data/got_dataset/209_Mockingbird__Game_of_Thrones_.txt',
#   'data/got_dataset/508_A_Game_of_Thrones__Second_Edition__card_game_.txt',
#   'data/got_dataset/474_Bronn__character_.txt',
#   'data/got_dataset/410_The_Bells__Game_of_Thrones_.txt',
#   'data/got_dataset/33_David_Benioff.txt',
#   'data/got_dataset/53_The_Lion_and_the_Rose.txt',
#   'data/got_dataset/119_Walk_of_Punishment.txt',
#   'data/got_dataset/54_Two_Swords__Game_of_Thrones_.txt',
#   'data/got_dataset/1_Dragonstone__Game_of_Thrones_episode_.txt',
#   'data/got_dataset/341_Ned_Stark.txt',
#   'data/got_dataset/80_A_Song_of_Ice_and_Fire_fandom.txt',
#   'data/got_dataset/57_The_Laws_of_Gods_and_Men.txt',
#   'data/got_dataset/27_Game_of_Thrones__Season_4__soundtrack_.txt',
#   'data/got_dataset/425_No_One__Game_of_Thrones_.txt',
#   'data/got_dataset/403_Jenny_of_Oldstones.txt',
#   'data/got_dataset/407_The_Long_Night__Game_of_Thrones_.txt',
#   'data/got_dataset/332_Sansa_Stark.txt',
#   'data/got_dataset/310_Mother_s_Mercy.txt',
#   'data/got_dataset/345_A_Game_of_Thrones__comics_.txt',
#   'data/got_dataset/0_Game_of_Thrones__season_8_.txt',
#   'data/got_dataset/160_Viserys_Targaryen.txt',
#   'data/got_dataset/456_Works_based_on_A_Song_of_Ice_and_Fire.txt',
#   'data/got_dataset/193_Lord_Snow.txt',
#   'data/got_dataset/304_Hardhome.txt',
#   'data/got_dataset/446_A_Golden_Crown.txt',
#   'data/got_dataset/262_Gilly__character_.txt',
#   'data/got_dataset/408_The_Last_of_the_Starks.txt',
#   'data/got_dataset/224_The_Night_Lands.txt',
#   'data/got_dataset/97_Tyrion_Lannister.txt',
#   'data/got_dataset/349_List_of_Game_of_Thrones_characters.txt',
#   'data/got_dataset/135_Game_of_Thrones__Season_7__soundtrack_.txt',
#   'data/got_dataset/228_Souad_Faress.txt',
#   'data/got_dataset/7_The_Spoils_of_War__Game_of_Thrones_.txt',
#   'data/got_dataset/56_First_of_His_Name.txt',
#   'data/got_dataset/317_The_Broken_Man.txt',
#   'data/got_dataset/348_The_Winds_of_Winter.txt',
#   'data/got_dataset/44_Daenerys_Targaryen.txt',
#   'data/got_dataset/211_The_Watchers_on_the_Wall.txt',
#   'data/got_dataset/68_The_Gift__Game_of_Thrones_.txt',
#   'data/got_dataset/78_The_Rains_of_Castamere.txt',
#   'data/got_dataset/477_A_Dance_with_Dragons.txt',
#   'data/got_dataset/130_Game_of_Thrones_title_sequence.txt',
#   'data/got_dataset/51_Iron_Throne__A_Song_of_Ice_and_Fire_.txt',
#   'data/got_dataset/148_Game_of_Thrones__Winter_Is_Coming.txt',
#   'data/got_dataset/347_Game_of_Thrones__season_2_.txt',
#   'data/got_dataset/394_Game_of_Thrones__2014_video_game_.txt',
#   'data/got_dataset/199_A_Storm_of_Swords.txt',
#   'data/got_dataset/87_Valar_Dohaeris.txt',
#   'data/got_dataset/23_Game_of_Thrones_Live_Concert_Experience.txt',
#   'data/got_dataset/69_The_Red_Woman.txt',
#   'data/got_dataset/21_The_Bear_and_the_Maiden_Fair__song_.txt',
#   'data/got_dataset/8_Eastwatch.txt',
#   'data/got_dataset/368_Jaime_Lannister.txt',
#   'data/got_dataset/76_Valar_Morghulis.txt',
#   'data/got_dataset/299_Rani_Mahal__TV_series_.txt',
#   'data/got_dataset/450_Baelor.txt',
#   'data/got_dataset/273_High_Sparrow.txt',
#   'data/got_dataset/447_You_Win_or_You_Die.txt',
#   'data/got_dataset/146_The_Sons_of_the_Dragon.txt',
#   'data/got_dataset/506_Game_of_Thrones_Theme.txt',
#   'data/got_dataset/369_Samwell_Tarly.txt',
#   'data/got_dataset/30_List_of_A_Song_of_Ice_and_Fire_characters.txt',
#   'data/got_dataset/39_Renly_Baratheon.txt',
#   'data/got_dataset/37_Joffrey_Baratheon.txt',
#   'data/got_dataset/22_The_Rains_of_Castamere__song_.txt',
#   'data/got_dataset/129_Second_Sons.txt',
#   'data/got_dataset/121_The_Bear_and_the_Maiden_Fair.txt',
#   'data/got_dataset/329_Robert_Baratheon.txt',
#   'data/got_dataset/67_Unbowed__Unbent__Unbroken.txt',
#   'data/got_dataset/439_Melisandre.txt',
#   'data/got_dataset/511_After_the_Thrones.txt',
#   'data/got_dataset/469_Outline_of_A_Song_of_Ice_and_Fire_franchise.txt',
#   'data/got_dataset/481_Sandor_Clegane.txt',
#   'data/got_dataset/331_Bran_Stark.txt',
#   'data/got_dataset/356_Tales_of_Dunk_and_Egg.txt',
#   'data/got_dataset/79_Thronecast.txt',
#   'data/got_dataset/102_The_Princess_and_the_Queen.txt',
#   'data/got_dataset/10_Beyond_the_Wall__Game_of_Thrones_.txt',
#   'data/got_dataset/367_Gregor_Clegane.txt',
#   'data/got_dataset/449_The_Pointy_End.txt',
#   'data/got_dataset/75_Blackwater__Game_of_Thrones_.txt',
#   'data/got_dataset/151_Ellaria_Sand.txt',
#   'data/got_dataset/485_Oathkeeper.txt',
#   'data/got_dataset/198_A_Clash_of_Kings.txt',
#   'data/got_dataset/346_Ygritte.txt',
#   'data/got_dataset/371_Cersei_Lannister.txt',
#   'data/got_dataset/197_A_Game_of_Thrones.txt',
#   'data/got_dataset/101_Titties_and_Dragons.txt',
#   'data/got_dataset/340_Roose_Bolton.txt',
#   'data/got_dataset/77_Game_of_Thrones_Ascent.txt',
#   'data/got_dataset/263_Tormund_Giantsbane.txt',
#   'data/got_dataset/359_Kill_the_Boy.txt',
#   'data/got_dataset/512_Home__Game_of_Thrones_.txt',
#   'data/got_dataset/487_Ramsay_Bolton.txt',
#   'data/got_dataset/400_Winterfell__Game_of_Thrones_episode_.txt',
#   'data/got_dataset/208_Robb_Stark.txt',
#   'data/got_dataset/127_The_Climb__Game_of_Thrones_.txt',
#   'data/got_dataset/52_Catch_the_Throne.txt',
#   'data/got_dataset/330_Oberyn_Martell.txt',
#   'data/got_dataset/365_A_Song_of_Ice_and_Fire_Roleplaying.txt',
#   'data/got_dataset/513_Oathbreaker__Game_of_Thrones_.txt',
#   'data/got_dataset/444_Cripples__Bastards__and_Broken_Things.txt',
#   'data/got_dataset/120_And_Now_His_Watch_Is_Ended.txt',
#   'data/got_dataset/2_Stormborn.txt',
#   'data/got_dataset/74_The_Prince_of_Winterfell.txt',
#   'data/got_dataset/443_The_Kingsroad.txt',
#   'data/got_dataset/202_A_Feast_for_Crows.txt',
#   'data/got_dataset/373_Tywin_Lannister.txt',
#   'data/got_dataset/40_Stannis_Baratheon.txt',
#   'data/got_dataset/218_Olenna_Tyrell.txt',
#   'data/got_dataset/84_List_of_awards_and_nominations_received_by_Game_of_Thrones.txt',
#   'data/got_dataset/3_The_Queen_s_Justice.txt',
#   'data/got_dataset/25_Game_of_Thrones__Season_2__soundtrack_.txt',
#   'data/got_dataset/12_Fire.txt',
#   'data/got_dataset/26_Game_of_Thrones__Season_3__soundtrack_.txt',
#   'data/got_dataset/358_A_Game_of_Thrones__Genesis.txt',
#   'data/got_dataset/133_Game_of_Thrones__Season_5__soundtrack_.txt',
#   'data/got_dataset/85_Game_of_Thrones__Seven_Kingdoms.txt',
#   'data/got_dataset/501_Khal_Drogo.txt',
#   'data/got_dataset/306_The_Dance_of_Dragons.txt',
#   'data/got_dataset/515_The_Door__Game_of_Thrones_.txt',
#   'data/got_dataset/402_A_Knight_of_the_Seven_Kingdoms__Game_of_Thrones_.txt',
#   'data/got_dataset/411_The_Iron_Throne__Game_of_Thrones_.txt'],
#  'node_id': 'DocumentStore'}

# %% [markdown]
# Once we have loaded the documents, we initialize our retriever and reader instances. To achieve this, we initialize the retriever and the reader components. BM25Retriever uses the bm25 scoring function to retrieve the initial set of documents. For the reader, we initialize the FARMReader object. This is based on deepset’s FARM framework, which can utilize the QA models from Hugging Face. In our case, we use the deepset/roberta-base-squad2 model as a reader. The use_gpu argument can be set appropriately based on whether your device has a GPU or not:

# %%
#!pip install farm-haystack[inference]

# %%
# !sudo apt update
# !sudo apt install build-essential curl
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh
# !source $HOME/.cargo/env
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 133 kB in 1s (129 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 32 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# curl is already the newest version (7.81.0-1ubuntu1.21).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
# info: downloading installer
# sh: 180: cannot open /dev/tty: No such device or address

# %%
# !pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (25.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (80.9.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (0.45.1)

# %%
# !pip install tokenizers --prefer-binary
# Out:
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<2.0,>=0.16.4->tokenizers) (2025.11.12)

# %%
# !pip install tokenizers==0.13.3
# Out:
# Collecting tokenizers==0.13.3
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> tokenizers

# %%
# !pip install transformers==4.32.1
# !pip install farm-haystack[inference]
# Out:
# Collecting transformers==4.32.1
#   Using cached transformers-4.32.1-py3-none-any.whl.metadata (118 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (2.32.4)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.32.1)
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.32.1) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.1) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.1) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers==4.32.1) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.32.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.32.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.32.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.32.1) (2025.11.12)
# Using cached transformers-4.32.1-py3-none-any.whl (7.5 MB)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> tokenizers
# Requirement already satisfied: farm-haystack[inference] in /usr/local/lib/python3.12/dist-packages (1.26.4.post0)
# Requirement already satisfied: boilerpy3 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (1.0.7)
# Requirement already satisfied: events in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.5)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.28.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (4.25.1)
# Requirement already satisfied: lazy-imports==0.3.1 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (10.8.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (3.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (11.3.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (4.5.1)
# Requirement already satisfied: posthog in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (7.5.1)
# Requirement already satisfied: prompthub-py==4.0.0 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (4.0.0)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (1.10.26)
# Requirement already satisfied: quantulum3 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.9.2)
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (2.32.4)
# Requirement already satisfied: requests-cache<1.0.0 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.9.8)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (1.6.1)
# Requirement already satisfied: sseclient-py in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (1.9.0)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (9.1.2)
# Requirement already satisfied: tiktoken>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (4.67.1)
# Requirement already satisfied: transformers<5.0,>=4.46 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (4.57.3)
# Requirement already satisfied: huggingface-hub>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (0.36.0)
# Requirement already satisfied: sentence-transformers<=3.0.0,>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from farm-haystack[inference]) (3.0.0)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from prompthub-py==4.0.0->farm-haystack[inference]) (6.0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2->farm-haystack[inference]) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack[inference]) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack[inference]) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack[inference]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->farm-haystack[inference]) (2025.11.12)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (25.3.0)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.12/dist-packages (from requests-cache<1.0.0->farm-haystack[inference]) (2.2.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (2.9.0+cpu)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (1.16.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack[inference]) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack[inference]) (25.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack[inference]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack[inference]) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.46->farm-haystack[inference]) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[inference]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[inference]) (1.2.0)
# Requirement already satisfied: accelerate>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.46; extra == "inference"->farm-haystack[inference]) (1.12.0)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.46; extra == "inference"->farm-haystack[inference]) (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from transformers[sentencepiece,torch]<5.0,>=4.46; extra == "inference"->farm-haystack[inference]) (5.29.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=0.26.0->transformers[sentencepiece,torch]<5.0,>=4.46; extra == "inference"->farm-haystack[inference]) (5.9.5)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->farm-haystack[inference]) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->farm-haystack[inference]) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (1.3.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->farm-haystack[inference]) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->farm-haystack[inference]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->farm-haystack[inference]) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers<=3.0.0,>=2.3.1->farm-haystack[inference]) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack[inference]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack[inference]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->farm-haystack[inference]) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack[inference]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack[inference]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->farm-haystack[inference]) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->farm-haystack[inference]) (1.17.0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog->farm-haystack[inference]) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog->farm-haystack[inference]) (1.9.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.12/dist-packages (from quantulum3->farm-haystack[inference]) (7.5.0)
# Requirement already satisfied: num2words in /usr/local/lib/python3.12/dist-packages (from quantulum3->farm-haystack[inference]) (0.5.14)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from inflect->quantulum3->farm-haystack[inference]) (4.4.4)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from num2words->quantulum3->farm-haystack[inference]) (0.6.2)

# %%
from haystack.nodes import BM25Retriever, TransformersReader

retriever = BM25Retriever(document_store=document_store)
reader = TransformersReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=False)
# Out:
# Device set to use cpu

# %% [markdown]
# We now create a pipeline that we can use to answer questions. After having initialized the retriever and reader in the previous step, we want to combine them for querying. The pipeline abstraction from the Haystack framework allows us to integrate the reader and retriever together using a series of pipelines that address different use cases. In this instance, we will use ExtractiveQAPipeline for our QA system. After the initialization of the pipeline, we generate the answer to a question from the Game of Thrones series. The run method takes the question as the query. The second argument, params, dictates how the results from the retriever and reader are combined to present the answer:

# %% [markdown]
# 1. "Retriever": {"top_k": 10}: The top_k keyword argument specifies that the top-k (in this case, 10) results from the retriever are used by the reader to search for the exact answer
# 2. "Reader": {"top_k": 5}: The top_k keyword argument specifies that the top-k (in this case, 5) results from the reader are presented as the output of the method:

# %%
from haystack.pipelines import ExtractiveQAPipeline

pipe = ExtractiveQAPipeline(reader, retriever)
prediction = pipe.run(
    query="Who is the father of Arya Stark?",
    params={"Retriever": {"top_k": 10}, "Reader": {"top_k": 5}}
)
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/question_answering.py:395: FutureWarning: Passing a list of SQuAD examples to the pipeline is deprecated and will be removed in v5. Inputs should be passed using the `question` and `context` keyword arguments instead.
#   warnings.warn(

# %% [markdown]
# We print the answer to our question. The system prints out the exact answer along with the associated context that it used to extract the answer from. Note that we use the value of all for the details argument. Using the all value for the same argument prints out start and end spans for the answer along with all the auxiliary information. Setting the value of medium for the details argument provides the relative score of each answer. This score can be used to filter out the results further based on the accuracy requirements of the system. Using the argument of medium presents only the answer and the context. We encourage you to make a suitable choice based on your requirements:

# %%
print_answers(prediction, details = "all")
# Out:
# 'Query: Who is the father of Arya Stark?'
# 'Answers:'
# [   <Answer {'answer': 'Ned', 'type': 'extractive', 'score': 1.9078067541122437, 'context': " the television series.\n\n====Season 1====\nArya accompanies her father Ned and her sister Sansa to King's Landing. Before their departure, Arya'", 'offsets_in_document': [{'start': 630, 'end': 633}], 'offsets_in_context': [{'start': 70, 'end': 73}], 'document_ids': ['7d3360fa29130e69ea6b2ba5c5a8f9c8'], 'meta': {'_split_id': 10}}>,
#     <Answer {'answer': 'Ned', 'type': 'extractive', 'score': 1.1788423657417297, 'context': "l disguised as a boy all along and is surprised to learn she is Arya, Ned Stark's daughter. After the Goldcloaks get help from Ser Amory Lorch ", 'offsets_in_document': [{'start': 848, 'end': 851}], 'offsets_in_context': [{'start': 70, 'end': 73}], 'document_ids': ['257088f56d2faba55e2ef2ebd19502dc'], 'meta': {'_split_id': 31}}>,
#     <Answer {'answer': 'Eddard', 'type': 'extractive', 'score': 0.9892422031261958, 'context': "Nymeria after a legendary warrior queen. She travels with her father, Eddard, to King's Landing when he is made Hand of the King. Before she leave", 'offsets_in_document': [{'start': 207, 'end': 213}], 'offsets_in_context': [{'start': 70, 'end': 76}], 'document_ids': ['9e3c863097d66aeed9992e0b6bf1f2f4'], 'meta': {'_split_id': 3}}>,
#     <Answer {'answer': 'Lord Eddard Stark', 'type': 'extractive', 'score': 0.84084153175354, 'context': 'Stark daughters.\n\nDuring the Tourney of the Hand to honour her father Lord Eddard Stark, Sansa Stark is enchanted by the knights performing in the event.  At', 'offsets_in_document': [{'start': 280, 'end': 297}], 'offsets_in_context': [{'start': 70, 'end': 87}], 'document_ids': ['5dbccad397381605eba063f71dd500a6'], 'meta': {'_split_id': 3}}>,
#     <Answer {'answer': 'Ned Stark', 'type': 'extractive', 'score': 0.710489809513092, 'context': "l disguised as a boy all along and is surprised to learn she is Arya, Ned Stark's daughter. After the Goldcloaks get help from Ser Amory Lorch and hi", 'offsets_in_document': [{'start': 848, 'end': 857}], 'offsets_in_context': [{'start': 70, 'end': 79}], 'document_ids': ['257088f56d2faba55e2ef2ebd19502dc'], 'meta': {'_split_id': 31}}>]
